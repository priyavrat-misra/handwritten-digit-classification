# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms
import numpy as np

from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.tensorboard import SummaryWriter
from utils import device, get_num_correct, RunBuilder
from network import Network

# %%
train_set = torchvision.datasets.MNIST(
    root='./data/',
    train=True,
    download=True,
    transform=transforms.ToTensor()
)
test_set = torchvision.datasets.MNIST(
    root='./data/',
    train=False,
    download=True,
    transform=transforms.ToTensor()
)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=1000)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
valid_size = 0.2

# obtain training indices that will be used for validation
num_train = len(train_set)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# %%
from collections import OrderedDict

params = OrderedDict(
    lr = [0.01, 0.003, 0.001, 0.0003],
    batch_size = [256, 512]
)

# %%
criterion = nn.CrossEntropyLoss()

for run in RunBuilder.get_runs(params):
    print(f'{run}')
    network = Network().to(device)
    train_loader = torch.utils.data.DataLoader(
        train_set,
        batch_size=run.batch_size,
        sampler=train_sampler,
        num_workers=1
        )
    valid_loader = torch.utils.data.DataLoader(
        train_set,
        batch_size=run.batch_size,
        sampler=valid_sampler,
        num_workers=1
        )
    optimizer = optim.Adam(network.parameters(), lr=run.lr)

    comment = f'-val-{run}'
    tb = SummaryWriter(comment=comment)

    valid_loss_min = np.Inf

    for epoch in range(10):

        train_loss = 0
        train_correct = 0

        ###################
        # train the model #
        ###################
        network.train()
        for batch in train_loader:
            images, labels = batch[0].to(device), batch[1].to(device)
            preds = network(images)
            loss = criterion(preds, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * run.batch_size
            train_correct += get_num_correct(preds, labels)

        tb.add_scalar('Train Loss', train_loss, epoch)
        tb.add_scalar('Train Accuracy', train_correct / len(train_loader.sampler), epoch)

        network.eval()
        with torch.no_grad():

            valid_loss = 0
            valid_correct = 0

            ######################
            # validate the model #
            ######################
            for batch in valid_loader:
                images, labels = batch[0].to(device), batch[1].to(device)
                preds = network(images)
                loss = criterion(preds, labels)

                valid_loss += loss.item() * run.batch_size
                valid_correct += get_num_correct(preds, labels)

            tb.add_scalar('Valid Loss', valid_loss, epoch)
            tb.add_scalar('Valid Accuracy', valid_correct / len(valid_loader.sampler), epoch)

            # print training/validation statistics
            # calculate average loss over an epoch
            train_loss = train_loss/len(train_loader.sampler)
            valid_loss = valid_loss/len(valid_loader.sampler)
            print(f'Epoch {epoch+1}: Training Loss: {train_loss:.6f} Validation Loss: {valid_loss:.6f}')

            # save model if validation loss has decreased
            if valid_loss <= valid_loss_min:
                print(f'\t valid_loss decreased ({valid_loss_min:.6f} --> {valid_loss:.6f})  saving model...')
                torch.save(network.state_dict(), f'./models/with_validation/model-{run}.ckpt')
                valid_loss_min = valid_loss

            # load the model with least validation loss
            network.load_state_dict(
                torch.load(
                    f'models/with_validation/model-{run}.ckpt',
                    map_location=device
                    )
                )

            test_loss = 0
            test_correct = 0

            ##################
            # test the model #
            ##################
            for batch in test_loader:
                images, labels = batch[0].to(device), batch[1].to(device)
                preds = network(images)
                loss = criterion(preds, labels)

                test_loss += loss.item() * images.size(0)
                test_correct += get_num_correct(preds, labels)

            tb.add_scalar('Test Loss', test_loss, epoch)
            tb.add_scalar('Test Accuracy', test_correct / len(test_set), epoch)


        for name, weight in network.named_parameters():
            tb.add_histogram(name, weight, epoch)
            tb.add_histogram(f'{name}.grad', weight.grad, epoch)
# Out:
# run(lr=0.01, batch_size=256)
# Epoch 1: Training Loss: 0.520361 Validation Loss: 0.076252
# 	 valid_loss decreased (inf --> 0.076252)  saving model...
# Epoch 2: Training Loss: 0.090637 Validation Loss: 0.052912
# 	 valid_loss decreased (0.076252 --> 0.052912)  saving model...
# Epoch 3: Training Loss: 0.064374 Validation Loss: 0.054400
# Epoch 4: Training Loss: 0.067970 Validation Loss: 0.052701
# 	 valid_loss decreased (0.052912 --> 0.052701)  saving model...
# Epoch 5: Training Loss: 0.052571 Validation Loss: 0.036333
# 	 valid_loss decreased (0.052701 --> 0.036333)  saving model...
# Epoch 6: Training Loss: 0.039477 Validation Loss: 0.037052
# Epoch 7: Training Loss: 0.045599 Validation Loss: 0.035199
# 	 valid_loss decreased (0.036333 --> 0.035199)  saving model...
# Epoch 8: Training Loss: 0.035710 Validation Loss: 0.033657
# 	 valid_loss decreased (0.035199 --> 0.033657)  saving model...
# Epoch 9: Training Loss: 0.031703 Validation Loss: 0.037189
# Epoch 10: Training Loss: 0.031481 Validation Loss: 0.039418
# run(lr=0.01, batch_size=512)
# Epoch 1: Training Loss: 0.795847 Validation Loss: 0.098784
# 	 valid_loss decreased (inf --> 0.098784)  saving model...
# Epoch 2: Training Loss: 0.107039 Validation Loss: 0.070989
# 	 valid_loss decreased (0.098784 --> 0.070989)  saving model...
# Epoch 3: Training Loss: 0.078420 Validation Loss: 0.047004
# 	 valid_loss decreased (0.070989 --> 0.047004)  saving model...
# Epoch 4: Training Loss: 0.060406 Validation Loss: 0.046226
# 	 valid_loss decreased (0.047004 --> 0.046226)  saving model...
# Epoch 5: Training Loss: 0.049263 Validation Loss: 0.043117
# 	 valid_loss decreased (0.046226 --> 0.043117)  saving model...
# Epoch 6: Training Loss: 0.044364 Validation Loss: 0.039966
# 	 valid_loss decreased (0.043117 --> 0.039966)  saving model...
# Epoch 7: Training Loss: 0.038733 Validation Loss: 0.036109
# 	 valid_loss decreased (0.039966 --> 0.036109)  saving model...
# Epoch 8: Training Loss: 0.032872 Validation Loss: 0.038438
# Epoch 9: Training Loss: 0.035562 Validation Loss: 0.036011
# 	 valid_loss decreased (0.036109 --> 0.036011)  saving model...
# Epoch 10: Training Loss: 0.030490 Validation Loss: 0.033319
# 	 valid_loss decreased (0.036011 --> 0.033319)  saving model...
# run(lr=0.003, batch_size=256)
# Epoch 1: Training Loss: 0.312826 Validation Loss: 0.083415
# 	 valid_loss decreased (inf --> 0.083415)  saving model...
# Epoch 2: Training Loss: 0.068046 Validation Loss: 0.069907
# 	 valid_loss decreased (0.083415 --> 0.069907)  saving model...
# Epoch 3: Training Loss: 0.048242 Validation Loss: 0.037958
# 	 valid_loss decreased (0.069907 --> 0.037958)  saving model...
# Epoch 4: Training Loss: 0.040537 Validation Loss: 0.042069
# Epoch 5: Training Loss: 0.040361 Validation Loss: 0.038404
# Epoch 6: Training Loss: 0.045354 Validation Loss: 0.044505
# Epoch 7: Training Loss: 0.045412 Validation Loss: 0.043965
# Epoch 8: Training Loss: 0.047876 Validation Loss: 0.060696
# Epoch 9: Training Loss: 0.049158 Validation Loss: 0.043346
# Epoch 10: Training Loss: 0.051671 Validation Loss: 0.039675
# run(lr=0.003, batch_size=512)
# Epoch 1: Training Loss: 0.384031 Validation Loss: 0.081795
# 	 valid_loss decreased (inf --> 0.081795)  saving model...
# Epoch 2: Training Loss: 0.072701 Validation Loss: 0.059806
# 	 valid_loss decreased (0.081795 --> 0.059806)  saving model...
# Epoch 3: Training Loss: 0.051686 Validation Loss: 0.041772
# 	 valid_loss decreased (0.059806 --> 0.041772)  saving model...
# Epoch 4: Training Loss: 0.036745 Validation Loss: 0.033441
# 	 valid_loss decreased (0.041772 --> 0.033441)  saving model...
# Epoch 5: Training Loss: 0.031383 Validation Loss: 0.031626
# 	 valid_loss decreased (0.033441 --> 0.031626)  saving model...
# Epoch 6: Training Loss: 0.027213 Validation Loss: 0.033739
# Epoch 7: Training Loss: 0.026051 Validation Loss: 0.041162
# Epoch 8: Training Loss: 0.026303 Validation Loss: 0.033830
# Epoch 9: Training Loss: 0.027696 Validation Loss: 0.041267
# Epoch 10: Training Loss: 0.031034 Validation Loss: 0.034806
# run(lr=0.001, batch_size=256)
# Epoch 1: Training Loss: 0.201549 Validation Loss: 0.061436
# 	 valid_loss decreased (inf --> 0.061436)  saving model...
# Epoch 2: Training Loss: 0.056115 Validation Loss: 0.042521
# 	 valid_loss decreased (0.061436 --> 0.042521)  saving model...
# Epoch 3: Training Loss: 0.041904 Validation Loss: 0.036680
# 	 valid_loss decreased (0.042521 --> 0.036680)  saving model...
# Epoch 4: Training Loss: 0.033392 Validation Loss: 0.033557
# 	 valid_loss decreased (0.036680 --> 0.033557)  saving model...
# Epoch 5: Training Loss: 0.024281 Validation Loss: 0.035678
# Epoch 6: Training Loss: 0.029791 Validation Loss: 0.032650
# 	 valid_loss decreased (0.033557 --> 0.032650)  saving model...
# Epoch 7: Training Loss: 0.021384 Validation Loss: 0.034008
# Epoch 8: Training Loss: 0.023765 Validation Loss: 0.032513
# 	 valid_loss decreased (0.032650 --> 0.032513)  saving model...
# Epoch 9: Training Loss: 0.019250 Validation Loss: 0.043194
# Epoch 10: Training Loss: 0.019445 Validation Loss: 0.031005
# 	 valid_loss decreased (0.032513 --> 0.031005)  saving model...
# run(lr=0.001, batch_size=512)
# Epoch 1: Training Loss: 0.289550 Validation Loss: 0.075842
# 	 valid_loss decreased (inf --> 0.075842)  saving model...
# Epoch 2: Training Loss: 0.067982 Validation Loss: 0.056244
# 	 valid_loss decreased (0.075842 --> 0.056244)  saving model...
# Epoch 3: Training Loss: 0.047635 Validation Loss: 0.052323
# 	 valid_loss decreased (0.056244 --> 0.052323)  saving model...
# Epoch 4: Training Loss: 0.039651 Validation Loss: 0.041078
# 	 valid_loss decreased (0.052323 --> 0.041078)  saving model...
# Epoch 5: Training Loss: 0.032508 Validation Loss: 0.034070
# 	 valid_loss decreased (0.041078 --> 0.034070)  saving model...
# Epoch 6: Training Loss: 0.026453 Validation Loss: 0.031022
# 	 valid_loss decreased (0.034070 --> 0.031022)  saving model...
# Epoch 7: Training Loss: 0.022107 Validation Loss: 0.041586
# Epoch 8: Training Loss: 0.022101 Validation Loss: 0.033255
# Epoch 9: Training Loss: 0.024167 Validation Loss: 0.042107
# Epoch 10: Training Loss: 0.022883 Validation Loss: 0.032814
# run(lr=0.0003, batch_size=256)
# Epoch 1: Training Loss: 0.355675 Validation Loss: 0.102303
# 	 valid_loss decreased (inf --> 0.102303)  saving model...
# Epoch 2: Training Loss: 0.091177 Validation Loss: 0.078792
# 	 valid_loss decreased (0.102303 --> 0.078792)  saving model...
# Epoch 3: Training Loss: 0.060968 Validation Loss: 0.051095
# 	 valid_loss decreased (0.078792 --> 0.051095)  saving model...
# Epoch 4: Training Loss: 0.049039 Validation Loss: 0.052037
# Epoch 5: Training Loss: 0.049723 Validation Loss: 0.049355
# 	 valid_loss decreased (0.051095 --> 0.049355)  saving model...
# Epoch 6: Training Loss: 0.039584 Validation Loss: 0.043934
# 	 valid_loss decreased (0.049355 --> 0.043934)  saving model...
# Epoch 7: Training Loss: 0.032980 Validation Loss: 0.047616
# Epoch 8: Training Loss: 0.033694 Validation Loss: 0.041918
# 	 valid_loss decreased (0.043934 --> 0.041918)  saving model...
# Epoch 9: Training Loss: 0.027668 Validation Loss: 0.043560
# Epoch 10: Training Loss: 0.028536 Validation Loss: 0.040397
# 	 valid_loss decreased (0.041918 --> 0.040397)  saving model...
# run(lr=0.0003, batch_size=512)
# Epoch 1: Training Loss: 0.481749 Validation Loss: 0.134165
# 	 valid_loss decreased (inf --> 0.134165)  saving model...
# Epoch 2: Training Loss: 0.109857 Validation Loss: 0.078461
# 	 valid_loss decreased (0.134165 --> 0.078461)  saving model...
# Epoch 3: Training Loss: 0.073258 Validation Loss: 0.062168
# 	 valid_loss decreased (0.078461 --> 0.062168)  saving model...
# Epoch 4: Training Loss: 0.057393 Validation Loss: 0.050531
# 	 valid_loss decreased (0.062168 --> 0.050531)  saving model...
# Epoch 5: Training Loss: 0.046632 Validation Loss: 0.044549
# 	 valid_loss decreased (0.050531 --> 0.044549)  saving model...
# Epoch 6: Training Loss: 0.039216 Validation Loss: 0.043875
# 	 valid_loss decreased (0.044549 --> 0.043875)  saving model...
# Epoch 7: Training Loss: 0.034386 Validation Loss: 0.045625
# Epoch 8: Training Loss: 0.034563 Validation Loss: 0.042446
# 	 valid_loss decreased (0.043875 --> 0.042446)  saving model...
# Epoch 9: Training Loss: 0.031357 Validation Loss: 0.040827
# 	 valid_loss decreased (0.042446 --> 0.040827)  saving model...
# Epoch 10: Training Loss: 0.027050 Validation Loss: 0.037426
# 	 valid_loss decreased (0.040827 --> 0.037426)  saving model...
